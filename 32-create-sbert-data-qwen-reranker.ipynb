# %% [markdown]
# # Improve the dataset used for SBERT finetuning
#
# The dataset used for finetuning the ModernBERT model for similarity looks strange with respect to the very opinionated similarity values. We can do better by using a (very good) reranking model and calculating the similarities with this.
#
# It turns out that these also improves the performance of the resulting finetuned model!

# %%
import torch
from transformers import AutoModel, AutoTokenizer, AutoModelForCausalLM

# %% [markdown]
# This is an instruction following model and needs to be prompted

# %%
def format_instruction(instruction, query, doc):
    output = "<Instruct>: {instruction}\n<Query>: {query}\n<Document>: {doc}".format(instruction=instruction,query=query, doc=doc)
    return output

# %%
def process_inputs(pairs):
    inputs = tokenizer(
        pairs, padding=False, truncation='longest_first',
        return_attention_mask=False, max_length=max_length - len(prefix_tokens) - len(suffix_tokens)
    )
    for i, ele in enumerate(inputs['input_ids']):
        inputs['input_ids'][i] = prefix_tokens + ele + suffix_tokens
    inputs = tokenizer.pad(inputs, padding=True, return_tensors="pt", max_length=max_length)
    for key in inputs:
        inputs[key] = inputs[key].to(model.device)
    return inputs

# %% [markdown]
# We are interested in the probabilities of yet and no, therefore we take a look at the last layer and get these:

# %%
@torch.no_grad()
def compute_logits(inputs, **kwargs):
    batch_scores = model(**inputs).logits[:, -1, :]
    true_vector = batch_scores[:, token_true_id]
    false_vector = batch_scores[:, token_false_id]
    batch_scores = torch.stack([false_vector, true_vector], dim=1)
    batch_scores = torch.nn.functional.log_softmax(batch_scores, dim=1)
    scores = batch_scores[:, 1].exp().tolist()
    return scores

# %%
# this is large and slow, but slightly better:
# model_name = "Qwen/Qwen3-Reranker-4B"
model_name = "Qwen/Qwen3-Reranker-0.6B"
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_side='left')
model = model = AutoModelForCausalLM.from_pretrained(model_name, dtype=torch.float16, attn_implementation="flash_attention_2").cuda().eval()

# %% [markdown]
# Use the *flawed* dataset again

# %%
from datasets import load_dataset
train_dataset = load_dataset("sentence-transformers/all-nli", "pair-score", split="train")

# %%
df = train_dataset.to_pandas()

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
df.head(20).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_63ee1_row0_col2, #T_63ee1_row3_col2, #T_63ee1_row8_col2, #T_63ee1_row9_col2, #T_63ee1_row11_col2, #T_63ee1_row12_col2, #T_63ee1_row15_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_63ee1_row1_col2, #T_63ee1_row5_col2, #T_63ee1_row6_col2, #T_63ee1_row10_col2, #T_63ee1_row13_col2, #T_63ee1_row16_col2, #T_63ee1_row19_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_63ee1_row2_col2, #T_63ee1_row4_col2, #T_63ee1_row7_col2, #T_63ee1_row14_col2, #T_63ee1_row17_col2, #T_63ee1_row18_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63ee1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63ee1_level0_col0" class="col_heading level0 col0" >sentence1</th>
#       <th id="T_63ee1_level0_col1" class="col_heading level0 col1" >sentence2</th>
#       <th id="T_63ee1_level0_col2" class="col_heading level0 col2" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63ee1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63ee1_row0_col0" class="data row0 col0" >A person on a horse jumps over a broken down airplane.</td>
#       <td id="T_63ee1_row0_col1" class="data row0 col1" >A person is training his horse for a competition.</td>
#       <td id="T_63ee1_row0_col2" class="data row0 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63ee1_row1_col0" class="data row1 col0" >A person on a horse jumps over a broken down airplane.</td>
#       <td id="T_63ee1_row1_col1" class="data row1 col1" >A person is at a diner, ordering an omelette.</td>
#       <td id="T_63ee1_row1_col2" class="data row1 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63ee1_row2_col0" class="data row2 col0" >A person on a horse jumps over a broken down airplane.</td>
#       <td id="T_63ee1_row2_col1" class="data row2 col1" >A person is outdoors, on a horse.</td>
#       <td id="T_63ee1_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63ee1_row3_col0" class="data row3 col0" >Children smiling and waving at camera</td>
#       <td id="T_63ee1_row3_col1" class="data row3 col1" >They are smiling at their parents</td>
#       <td id="T_63ee1_row3_col2" class="data row3 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63ee1_row4_col0" class="data row4 col0" >Children smiling and waving at camera</td>
#       <td id="T_63ee1_row4_col1" class="data row4 col1" >There are children present</td>
#       <td id="T_63ee1_row4_col2" class="data row4 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_63ee1_row5_col0" class="data row5 col0" >Children smiling and waving at camera</td>
#       <td id="T_63ee1_row5_col1" class="data row5 col1" >The kids are frowning</td>
#       <td id="T_63ee1_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_63ee1_row6_col0" class="data row6 col0" >A boy is jumping on skateboard in the middle of a red bridge.</td>
#       <td id="T_63ee1_row6_col1" class="data row6 col1" >The boy skates down the sidewalk.</td>
#       <td id="T_63ee1_row6_col2" class="data row6 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_63ee1_row7_col0" class="data row7 col0" >A boy is jumping on skateboard in the middle of a red bridge.</td>
#       <td id="T_63ee1_row7_col1" class="data row7 col1" >The boy does a skateboarding trick.</td>
#       <td id="T_63ee1_row7_col2" class="data row7 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_63ee1_row8_col0" class="data row8 col0" >A boy is jumping on skateboard in the middle of a red bridge.</td>
#       <td id="T_63ee1_row8_col1" class="data row8 col1" >The boy is wearing safety equipment.</td>
#       <td id="T_63ee1_row8_col2" class="data row8 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_63ee1_row9_col0" class="data row9 col0" >An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</td>
#       <td id="T_63ee1_row9_col1" class="data row9 col1" >An older man drinks his juice as he waits for his daughter to get off work.</td>
#       <td id="T_63ee1_row9_col2" class="data row9 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_63ee1_row10_col0" class="data row10 col0" >An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</td>
#       <td id="T_63ee1_row10_col1" class="data row10 col1" >A boy flips a burger.</td>
#       <td id="T_63ee1_row10_col2" class="data row10 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_63ee1_row11_col0" class="data row11 col0" >An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</td>
#       <td id="T_63ee1_row11_col1" class="data row11 col1" >An elderly man sits in a small shop.</td>
#       <td id="T_63ee1_row11_col2" class="data row11 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_63ee1_row12_col0" class="data row12 col0" >Two blond women are hugging one another.</td>
#       <td id="T_63ee1_row12_col1" class="data row12 col1" >Some women are hugging on vacation.</td>
#       <td id="T_63ee1_row12_col2" class="data row12 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_63ee1_row13_col0" class="data row13 col0" >Two blond women are hugging one another.</td>
#       <td id="T_63ee1_row13_col1" class="data row13 col1" >The women are sleeping.</td>
#       <td id="T_63ee1_row13_col2" class="data row13 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_63ee1_row14_col0" class="data row14 col0" >Two blond women are hugging one another.</td>
#       <td id="T_63ee1_row14_col1" class="data row14 col1" >There are women showing affection.</td>
#       <td id="T_63ee1_row14_col2" class="data row14 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_63ee1_row15_col0" class="data row15 col0" >A few people in a restaurant setting, one of them is drinking orange juice.</td>
#       <td id="T_63ee1_row15_col1" class="data row15 col1" >The people are eating omelettes.</td>
#       <td id="T_63ee1_row15_col2" class="data row15 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_63ee1_row16_col0" class="data row16 col0" >A few people in a restaurant setting, one of them is drinking orange juice.</td>
#       <td id="T_63ee1_row16_col1" class="data row16 col1" >The people are sitting at desks in school.</td>
#       <td id="T_63ee1_row16_col2" class="data row16 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63ee1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_63ee1_row17_col0" class="data row17 col0" >A few people in a restaurant setting, one of them is drinking orange juice.</td>
#       <td id="T_63ee1_row17_col1" class="data row17 col1"

# %% [markdown]
# Get the tokens ids for `yes` and `no`, used for calculating the probabilities later

# %%
token_false_id = tokenizer.convert_tokens_to_ids("no")
token_true_id = tokenizer.convert_tokens_to_ids("yes")

# %% [markdown]
# We use the Qwen chat template (more about that later) and a special system prompt:

# %%
max_length = 8192

prefix = "<|im_start|>system\nJudge whether the documents are similar . Note that the answer can only be \"yes\" or \"no\".<|im_end|>\n<|im_start|>user\n"
suffix = "<|im_end|>\n<|im_start|>assistant\n<think>\n\n</think>\n\n"
prefix_tokens = tokenizer.encode(prefix, add_special_tokens=False)
suffix_tokens = tokenizer.encode(suffix, add_special_tokens=False)

# %% [markdown]
# Create a temporary dataframe containing the start of the dataset and some arbitrary samples:

# %%
dft = pd.concat([df.head(20), df.sample(20, random_state=42)])

# %% [markdown]
# Create the instruct codes for prompting the LLM:

# %%
pairs = [format_instruction("Given two sentences, calculate their similarity", query, doc) 
           for query, doc in zip(dft["sentence1"], dft["sentence2"])]

# %% [markdown]
# Run the actual reranking process:

# %%
# %%time
# Tokenize the input texts
max_length = 8192
inputs = process_inputs(pairs)
scores = compute_logits(inputs)
# Out:
# You're using a Qwen2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /home/cwinkler/uv/finetuning-env/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2752: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# CPU times: user 243 ms, sys: 140 ms, total: 383 ms
# Wall time: 377 ms

# %%
# integrate scores
dft["scores"] = scores

# %%
dft.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6cc92_row0_col2, #T_6cc92_row3_col2, #T_6cc92_row8_col2, #T_6cc92_row9_col2, #T_6cc92_row11_col2, #T_6cc92_row12_col2, #T_6cc92_row15_col2, #T_6cc92_row20_col2, #T_6cc92_row24_col2, #T_6cc92_row25_col2, #T_6cc92_row26_col2, #T_6cc92_row28_col2, #T_6cc92_row29_col2, #T_6cc92_row32_col2, #T_6cc92_row33_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_6cc92_row0_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6cc92_row1_col2, #T_6cc92_row1_col3, #T_6cc92_row5_col2, #T_6cc92_row5_col3, #T_6cc92_row6_col2, #T_6cc92_row10_col2, #T_6cc92_row10_col3, #T_6cc92_row13_col2, #T_6cc92_row13_col3, #T_6cc92_row15_col3, #T_6cc92_row16_col2, #T_6cc92_row16_col3, #T_6cc92_row19_col2, #T_6cc92_row19_col3, #T_6cc92_row27_col2, #T_6cc92_row31_col2, #T_6cc92_row31_col3, #T_6cc92_row34_col2, #T_6cc92_row36_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6cc92_row2_col2, #T_6cc92_row4_col2, #T_6cc92_row7_col2, #T_6cc92_row14_col2, #T_6cc92_row17_col2, #T_6cc92_row18_col2, #T_6cc92_row18_col3, #T_6cc92_row21_col2, #T_6cc92_row21_col3, #T_6cc92_row22_col2, #T_6cc92_row22_col3, #T_6cc92_row23_col2, #T_6cc92_row23_col3, #T_6cc92_row30_col2, #T_6cc92_row35_col2, #T_6cc92_row35_col3, #T_6cc92_row36_col3, #T_6cc92_row37_col2, #T_6cc92_row37_col3, #T_6cc92_row38_col2, #T_6cc92_row38_col3, #T_6cc92_row39_col2, #T_6cc92_row39_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6cc92_row2_col3, #T_6cc92_row14_col3, #T_6cc92_row33_col3 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_6cc92_row3_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6cc92_row4_col3 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_6cc92_row6_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6cc92_row7_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_6cc92_row8_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_6cc92_row9_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_6cc92_row11_col3 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_6cc92_row12_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_6cc92_row17_col3, #T_6cc92_row30_col3 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_6cc92_row20_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_6cc92_row24_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_6cc92_row25_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6cc92_row26_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_6cc92_row27_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_6cc92_row28_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6cc92_row29_col3, #T_6cc92_row32_col3 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_6cc92_row34_col3 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6cc92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cc92_level0_col0" class="col_heading level0 col0" >sentence1</th>
#       <th id="T_6cc92_level0_col1" class="col_heading level0 col1" >sentence2</th>
#       <th id="T_6cc92_level0_col2" class="col_heading level0 col2" >score</th>
#       <th id="T_6cc92_level0_col3" class="col_heading level0 col3" >scores</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cc92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6cc92_row0_col0" class="data row0 col0" >A person on a horse jumps over a broken down airplane.</td>
#       <td id="T_6cc92_row0_col1" class="data row0 col1" >A person is training his horse for a competition.</td>
#       <td id="T_6cc92_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_6cc92_row0_col3" class="data row0 col3" >0.008514</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6cc92_row1_col0" class="data row1 col0" >A person on a horse jumps over a broken down airplane.</td>
#       <td id="T_6cc92_row1_col1" class="data row1 col1" >A person is at a diner, ordering an omelette.</td>
#       <td id="T_6cc92_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_6cc92_row1_col3" class="data row1 col3" >0.000045</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6cc92_row2_col0" class="data row2 col0" >A person on a horse jumps over a broken down airplane.</td>
#       <td id="T_6cc92_row2_col1" class="data row2 col1" >A person is outdoors, on a horse.</td>
#       <td id="T_6cc92_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6cc92_row2_col3" class="data row2 col3" >0.992188</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6cc92_row3_col0" class="data row3 col0" >Children smiling and waving at camera</td>
#       <td id="T_6cc92_row3_col1" class="data row3 col1" >They are smiling at their parents</td>
#       <td id="T_6cc92_row3_col2" class="data row3 col2" >0.500000</td>
#       <td id="T_6cc92_row3_col3" class="data row3 col3" >0.031158</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6cc92_row4_col0" class="data row4 col0" >Children smiling and waving at camera</td>
#       <td id="T_6cc92_row4_col1" class="data row4 col1" >There are children present</td>
#       <td id="T_6cc92_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_6cc92_row4_col3" class="data row4 col3" >0.845703</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6cc92_row5_col0" class="data row5 col0" >Children smiling and waving at camera</td>
#       <td id="T_6cc92_row5_col1" class="data row5 col1" >The kids are frowning</td>
#       <td id="T_6cc92_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_6cc92_row5_col3" class="data row5 col3" >0.003885</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6cc92_row6_col0" class="data row6 col0" >A boy is jumping on skateboard in the middle of a red bridge.</td>
#       <td id="T_6cc92_row6_col1" class="data row6 col1" >The boy skates down the sidewalk.</td>
#       <td id="T_6cc92_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_6cc92_row6_col3" class="data row6 col3" >0.039093</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6cc92_row7_col0" class="data row7 col0" >A boy is jumping on skateboard in the middle of a red bridge.</td>
#       <td id="T_6cc92_row7_col1" class="data row7 col1" >The boy does a skateboarding trick.</td>
#       <td id="T_6cc92_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_6cc92_row7_col3" class="data row7 col3" >0.983398</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6cc92_row8_col0" class="data row8 col0" >A boy is jumping on skateboard in the middle of a red bridge.</td>
#       <td id="T_6cc92_row8_col1" class="data row8 col1" >The boy is wearing safety equipment.</td>
#       <td id="T_6cc92_row8_col2" class="data row8 col2" >0.500000</td>
#       <td id="T_6cc92_row8_col3" class="data row8 col3" >0.149048</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6cc92_row9_col0" class="data row9 col0" >An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</td>
#       <td id="T_6cc92_row9_col1" class="data row9 col1" >An older man drinks his juice as he waits for his daughter to get off work.</td>
#       <td id="T_6cc92_row9_col2" class="data row9 col2" >0.500000</td>
#       <td id="T_6cc92_row9_col3" class="data row9 col3" >0.855957</td>
#     </tr>
#     <tr>
#       <th id="T_6cc92_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6cc92_row10_col0" class="data row10 col0" >An older man sits wi
